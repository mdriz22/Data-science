# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid',context='notebook')
cols=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']

# %%
import numpy as np
cm= np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='2f',annot_kws={'size':5},yticklabels=cols,xticklabels=cols)
plt.show()

# %%
class LinearRegressionGD(object):
def __init__(self, eta=0.001, n_iter=20):
self.eta = eta
self.n_iter = n_iter
def fit(self, X, y):
self.w_ = np.zeros(1 + X.shape[1])
self.cost_ = []
for i in range(self.n_iter):
output = self.net_input(X)
errors = (y - output)
self.w_[1:] += self.eta * X.T.dot(errors)
self.w_[0] += self.eta * errors.sum()
cost = (errors**2).sum() / 2.0
self.cost_.append(cost)
return self
def net_input(self, X):
return np.dot(X, self.w_[1:]) + self.w_[0]
def predict(self, X):
return self.net_input(X)
X = df[['Age']].values
y = df['Pregnancies'].values
from sklearn.preprocessing import StandardScaler sc_x = StandardScaler() sc_y =
StandardScaler()
X_std = sc_x.fit_transform(X)
 y_std = sc_y.fit_transform(y)
lr = LinearRegressionGD()
lr.fit(X_std, y_std)
plt.plot(range(1, lr.n_iter+1), lr.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.show()
# Out:
#   Input In [3]
#     def __init__(self, eta=0.001, n_iter=20):
#     ^
# IndentationError: expected an indented block

# %%
import matplotlib.pyplot as plt
def lin_regplot(X, y, model):
  plt.scatter(X, y, c='blue')
  plt.plot(X, model.predict(X), color='red')
  return Nonelin_regplot(X_std, y_std, lr)
plt.xlabel('Age (standardized)')
plt.ylabel('Pregnancies(standardized)')
plt.show()

# %%
age_std = sc_x.transform([20])
pregnancy_std = lr.predict(age_std)
print("Pregnancy: %.3f" %sc_y.inverse_transform(price_std))
print('Slope: %.3f' % lr.w_[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 age_std = sc_x.transform([20])
#       2 pregnancy_std = lr.predict(age_std)
#       3 print("Pregnancy: %.3f" %sc_y.inverse_transform(price_std))
#
# NameError: name 'sc_x' is not defined

# %%
from sklearn.model_selection import
train_test_split train_x, test_x, train_y, test_y =
train_test_split(X,Y,test_size=0.3,random_state=99)
train_x.shape, train_y.shape
from sklearn.linear_model import MultipleRegression
le = MultipleRegression()
le.fit(train_x,train_y)
y_pred = le.predict(test_x)
y_pred
result = pd.DataFrame({'Actual': test_y, 'Predict' : y_pred})
resul
# Out:
#   Input In [8]
#     from sklearn.model_selection import
#                                        ^
# SyntaxError: invalid syntax

# %%
print ('coefficient', le.coef_)
print('intercept', le.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 print ('coefficient', le.coef_)
#       2 print('intercept', le.intercept_)
#
# NameError: name 'le' is not defined

# %%
import datacompy
compare = datacompy.Compare(df1,df2,join_columns='acct_id', abs_tol=0.0001,rel_tol=0,df1_name='olddiabetes',df2_name='newdiabetes')
print(compare.report())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 import datacompy
#       2 compare = datacompy.Compare(df1,df2,join_columns='acct_id', abs_tol=0.0001,rel_tol=0,df1_name='olddiabetes',df2_name='newdiabetes')
#       3 print(compare.report())
#
# ModuleNotFoundError: No module named 'datacompy'
